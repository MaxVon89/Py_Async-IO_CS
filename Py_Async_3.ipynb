# %% [markdown]
# ## Corountines
# <p>Created when exec. async funcs.</p>
#
# ## Tasks
# <p>Wrapped coroutines, can be awaited, queued, etc.<br>
# Can be piled-up, and ran when the event loop has time.</br>
# Tasks are futures under the hood.
# </p>
