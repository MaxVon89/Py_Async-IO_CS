# %% [markdown]
# # AsyncIO
#
# ## Concurrency
#
# Synchronuous: 1 -> wait -> 2 -> wait -> 3
#
# <p>Asynchronuous: 1 -> wait </p>
# <p>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp-> 2 -> wait </p>
# <p>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp-> 3</p>

# %% [markdown]
# ## Event Loop

# %% [markdown]
# ## Coroutines

# %%
#Coroutine func.
#Coroutine obj.

import asyncio
from datetime import datetime

async def main():
    print('start of the main coroutine')
    await

asyncio.run(main())

# %%
import asyncio
import time

async def fetchData(timeDelay):
    print("Fetching data...")
    await asyncio.sleep(timeDelay)
    print("Data fetched")
    return {'data':'some data'}


async def main():
    print('start of main coroutine')
    task1 = fetchData(3)
    result = await task1
    print(f"Received {result}\nEnd of main coroutine")


# asyncio.run(main()) #doesn't work in VSC & JPy NB

await main()
# Out:
# start of main coroutine
# Fetching data...
# Data fetched
# Received {'data': 'some data'}
# End of main coroutine

# %%
import asyncio
import time

async def fetchData(timeDelay):
    print("Fetching data...")
    await asyncio.sleep(timeDelay)
    print("Data fetched")
    return {'data':'some data'}


async def main():
    print('start of main coroutine')
    task1 = fetchData(3)
    print(f"Received {result}")
    print("End of main coroutine")

    result = await task1

# asyncio.run(main()) #doesn't work in VSC & JPy NB

await main()
# Out:
# start of main coroutine
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 21
#      17     result = await task1
#      19 # asyncio.run(main()) #doesn't work in VSC & JPy NB
# ---> 21 await main()
#
# Cell In[9], line 14, in main()
#      12 print('start of main coroutine')
#      13 task1 = fetchData(3)
# ---> 14 print(f"Received {result}")
#      15 print("End of main coroutine")
#      17 result = await task1
#
# UnboundLocalError: cannot access local variable 'result' where it is not associated with a value

# %%
async def fetchData2(timeDelay2, ID):
    print(f"Fetching data for process {ID}")
    await asyncio.sleep(timeDelay2)
    print(f"Data fetched: data{ID}")

async def main():
    task1 = fetchData2(3, 1)
    task2 = fetchData2(3, 2)

    result1 = await task1
    result2 = await task2


await main()
# Out:
# Fetching data for process 1
# Data fetched: data1
# Fetching data for process 2
# Data fetched: data2

# %%
async def fetchData3(timeDelay3, ID):
    print(f"Fetching data for process {ID}")
    await asyncio.sleep(timeDelay3)
    print(f"Data fetched: data{ID}")

async def main():
    # t1 = time.perf_counter()
    task1 = fetchData3(3, 1)
    result1 = await task1

    task2 = fetchData3(3, 2)
    result2 = await task2
    # t2 = time.perf_counter()
    # print(t2-t1)
    return result1, result2

await main()
# Out:
# Fetching data for process 1
# Data fetched: data1
# Fetching data for process 2
# Data fetched: data2
# (None, None)

# %%
async def fetchData4(timeDelay, ID):
    print(f"fetching data for process ID {ID}. ")
    await asyncio.sleep(timeDelay)
    print(f"data fetched.")
    return {'data' : 'somedata'}


async def main():
    task3 = asyncio.create_task(fetchData4(2, 3))
    result3 = await task3
    
    task4 = asyncio.create_task(fetchData4(2, 4))
    result4 = await task4

    print(result3, result4)


await main()
# Out:
# fetching data for process ID 3.
# data fetched.
# fetching data for process ID 4.
# data fetched.
# None None
