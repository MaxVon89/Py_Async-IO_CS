# %% [markdown]
# # AsyncIO

# %% [markdown]
# ## Concurrency
#
# ### Syncronuous Code:
#     One after the other, sequential
#
# ### Asyncronuous Code:
#
# AsyncIO is IO Bound
# AsyncIO is single threaded, it is NOT multithreaded.
# Tasks voluntarily give up control, AKA cooperative multitasking
# Creates processes

# %%
#Generators (quick)
#Wrong:

def cubedNums(nums):
    for num in nums:
        yield num^3


currNum = cubedNums(3)

for num in currNum:
    print num
# Out:
#   Cell In[4], line 12
#     print num
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
def cubedNums(nums):
    for num in nums:
        yield num**3

currNum = cubedNums([3])

for nume in currNum:
    print(nume)
# Out:
# 27

# %%
#Comprehensions in Py

currNums = [1,2,3]
num3 = (num1*num1 for num1 in currNums)
# num3 = (print(num1*num1) for num1 in currNums)

print(num3)

print(list(num3))

for n in num3:
    print(n)
# Out:
# <generator object <genexpr> at 0x000001FC8B0E2670>
# [1, 4, 9]

# %% [markdown]
# ## Benefit
# Doesn't hold all the values in the memory readily, hence mem. effcnt.
